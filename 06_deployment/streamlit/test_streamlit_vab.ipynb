# %%
import pandas as pd

# %%
df_global = pd.read_csv('results_games_2022.csv')
df_global.head()
# Out:
#    Unnamed: 0  season  week        date  awayteam hometeam  \
# 0           0    2022     5  2022-10-06     Colts  Broncos
# 1           1    2022     5  2022-10-09    Giants  Packers
# 2           2    2022     5  2022-10-09  Steelers    Bills
# 3           3    2022     5  2022-10-09  Chargers   Browns
# 4           4    2022     5  2022-10-09     Bears  Vikings
#
#                       stadium          location  winner  proba_away  \
# 0  Empower Field at Mile High        Denver, CO       1      0.4868
# 1   Tottenham Hotspur Stadium            London       1      0.1381
# 2            Highmark Stadium  Orchard Park, NY       1      0.4714
# 3         FirstEnergy Stadium     Cleveland, OH       0      0.5341
# 4           U.S. Bank Stadium   Minneapolis, MN       1      0.3952
#
#    proba_home
# 0      0.5132
# 1      0.8619
# 2      0.5286
# 3      0.4659
# 4      0.6048

# %%
df_global.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  272 non-null    int64
#  1   season      272 non-null    int64
#  2   week        272 non-null    int64
#  3   date        272 non-null    object
#  4   awayteam    272 non-null    object
#  5   hometeam    272 non-null    object
#  6   stadium     272 non-null    object
#  7   location    272 non-null    object
#  8   winner      272 non-null    int64
#  9   proba_away  272 non-null    float64
#  10  proba_home  272 non-null    float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 23.5+ KB

# %%
df_global['game'] = df_global[['hometeam', 'awayteam']].agg(' vs '.join, axis=1)
df_global.head()
# Out:
#    Unnamed: 0  season  week        date  awayteam hometeam  \
# 0           0    2022     5  2022-10-06     Colts  Broncos
# 1           1    2022     5  2022-10-09    Giants  Packers
# 2           2    2022     5  2022-10-09  Steelers    Bills
# 3           3    2022     5  2022-10-09  Chargers   Browns
# 4           4    2022     5  2022-10-09     Bears  Vikings
#
#                       stadium          location  winner  proba_away  \
# 0  Empower Field at Mile High        Denver, CO       1      0.4868
# 1   Tottenham Hotspur Stadium            London       1      0.1381
# 2            Highmark Stadium  Orchard Park, NY       1      0.4714
# 3         FirstEnergy Stadium     Cleveland, OH       0      0.5341
# 4           U.S. Bank Stadium   Minneapolis, MN       1      0.3952
#
#    proba_home                game
# 0      0.5132    Broncos vs Colts
# 1      0.8619   Packers vs Giants
# 2      0.5286   Bills vs Steelers
# 3      0.4659  Browns vs Chargers
# 4      0.6048    Vikings vs Bears
