# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import  OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
# import ensemble methods
from xgboost import XGBClassifier
# import base estimators
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, ConfusionMatrixDisplay, RocCurveDisplay

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) # to avoid deprecation warnings

# %%
os.getcwd()
# Out:
# 'c:\\Users\\sylva\\Desktop\\nflpredictor\\nfl\\03_modelisation\\03_model3_XGBoost'

# %%
df = pd.read_csv("../../04_datasets/nfl_dataset_vf.csv", index_col=0)
dataset = pd.read_csv("../../04_datasets/nfl_dataset_vf.csv", index_col=0)

# %%
# Separate target variable Y from features X
print("Separating labels from features...")
target_variable = "winner_home"

X = dataset.drop(target_variable, axis = 1)
features_drop_list = {'idgame', 'location'}
X.drop(features_drop_list, axis=1, inplace=True)

Y = dataset.loc[:,target_variable]

# Automatically detect names of numeric/categorical columns
numeric_features = []
categorical_features = []
for i,t in X.dtypes.iteritems():
    if ('float' in str(t)) or ('int' in str(t)) :
        numeric_features.append(i)
    else :
        categorical_features.append(i)

print('Found numeric features ', numeric_features)
print('Found categorical features ', categorical_features)

print("Dividing into train and test sets...")
# WARNING : don't forget stratify=Y for classification problems
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0, stratify = Y)

# Create pipeline for numeric features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')), # missing values will be replaced by columns' mean
    ('scaler', StandardScaler())
])

# Create pipeline for categorical features
#categorical_transformer = OneHotEncoder(drop='first') # no missing values in categorical data, so we only need the OHE

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')), # missing values will be replaced by most frequent value
    ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore')) # first column will be dropped to avoid creating correlations between features
    ])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Preprocessings on train set
print("Performing preprocessings on train set...")
print(X_train.head())
X_train = preprocessor.fit_transform(X_train)
print('...Done preprocessing train set.')
print(X_train)
print('...Done.')
print(X_train[0:5]) # MUST use this syntax because X_train is a numpy array and not a pandas DataFrame anymore
print()
# Label encoding
print("Encoding labels...")
print(Y_train.head())
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
print("...Done")
print(Y_train[0:5])

# Preprocessings on test set
print("Performing preprocessings on test set...")
print(X_test.head()) 
X_test = preprocessor.transform(X_test) # Don't fit again !! The test set is used for validating decisions
# we made based on the training set, therefore we can only apply transformations that were parametered using the training set.
# Otherwise this creates what is called a leak from the test set which will introduce a bias in all your results.
print('...Done.')
print(X_test[0:5,:]) # MUST use this syntax because X_test is a numpy array and not a pandas DataFrame anymore
print()
# Label encoding
print("Encoding labels...")
print(Y_test[0:5])
Y_test = encoder.transform(Y_test)
print("...Done")
print(Y_test[0:5])

model = XGBClassifier(
    objective= 'binary:logistic',
    nthread=-1,
    seed=42,
    learning_rate= 0.1, 
    max_depth= 2,
    min_child_weight= 3,
    n_estimators= 140
    )

model.fit(X_train, Y_train)
# Out:
# Separating labels from features...
# Found numeric features  ['season', 'week', 'temperature', 'humidity', 'wind', 'streak_away', 'pass_yds_MA_5_away', 'pass_td_MA_5_away', 'rush_yds_MA_5_away', 'rush_td_MA_5_away', 'rec_yds_MA_5_away', 'rec_td_MA_5_away', 'fumbles_MA_5_away', 'fumbles_rec_MA_5_away', 'defense_sacks_MA_5_away', 'defense_td_MA_5_away', 'interceptions_MA_5_away', 'interceptions_td_MA_5_away', 'kicks_return_yds_MA_5_away', 'kicks_return_td_MA_5_away', 'punt_return_yds_MA_5_away', 'kicking_pts_MA_5_away', 'streak_home', 'pass_yds_MA_5_home', 'pass_td_MA_5_home', 'rush_yds_MA_5_home', 'rush_td_MA_5_home', 'rec_yds_MA_5_home', 'rec_td_MA_5_home', 'fumbles_MA_5_home', 'fumbles_rec_MA_5_home', 'defense_sacks_MA_5_home', 'defense_td_MA_5_home', 'interceptions_MA_5_home', 'interceptions_td_MA_5_home', 'kicks_return_yds_MA_5_home', 'kicks_return_td_MA_5_home', 'punt_return_yds_MA_5_home', 'kicking_pts_MA_5_home', 'delta_day_away', 'delta_day_home', 'people', 'month', 'dayofmonth', 'dayofweek']
# Found categorical features  ['awayteam', 'hometeam', 'home_coach', 'away_coach', 'weather_type', 'stade']
# Dividing into train and test sets...
# Performing preprocessings on train set...
#       season  week    awayteam  hometeam      home_coach      away_coach  \
# 642     2019    13    Patriots    Texans    Bill O'Brien  Bill Belichick
# 1008    2020     3  Buccaneers   Broncos      Vic Fangio    Bruce Arians
# 280     2018    10     Falcons    Browns  Gregg Williams       Dan Quinn
# 1200    2021    13      Giants  Dolphins    Brian Flores       Joe Judge
# 1183    2021     6       Bills    Titans     Mike Vrabel  Sean McDermott
#
#      weather_type  temperature  humidity  wind  ...  \
# 642           NaN          6.0      32.0   4.0  ...
# 1008       cloudy         55.0      39.0   7.0  ...
# 280         sunny         36.0      56.0   9.0  ...
# 1200        sunny         82.0      54.0   9.0  ...
# 1183          NaN         65.0      43.0   0.0  ...
#
#       kicks_return_td_MA_5_home  punt_return_yds_MA_5_home  \
# 642                         0.0                       11.6
# 1008                        0.0                       13.0
# 280                         0.0                       29.4
# 1200                        0.0                       15.8
# 1183                        0.0                       24.0
#
#       kicking_pts_MA_5_home  delta_day_away  delta_day_home  \
# 642                     7.4             7.0            10.0
# 1008                    6.2             7.0             7.0
# 280                     4.8             7.0             7.0
# 1200                    6.6             7.0             7.0
# 1183                    7.6             7.0             8.0
#
#                            stade  people  month  dayofmonth  dayofweek
# 642                  NRG Stadium   100.0     12           2          0
# 1008  Empower Field at Mile High     7.0      9          27          6
# 280          FirstEnergy Stadium    92.0     11          11          6
# 1200           Hard Rock Stadium   100.0     12           5          6
# 1183              Nissan Stadium   100.0     10          19          1
#
# [5 rows x 51 columns]
# ...Done preprocessing train set.
#   (0, 0)	-0.03834271189808886
#   (0, 1)	0.7518290617924952
#   (0, 2)	-2.3439275634157872
#   (0, 3)	-1.470415014097908
#   (0, 4)	-0.21739809590675968
#   (0, 5)	0.693627686875634
#   (0, 6)	-0.12862282471574757
#   (0, 7)	-0.591271746491325
#   (0, 8)	-1.272350630929766
#   (0, 9)	-0.22548028197690959
#   (0, 10)	-0.1298722676435955
#   (0, 11)	-0.5914285580153164
#   (0, 12)	-1.2097611110445048
#   (0, 13)	1.8338472681773395
#   (0, 14)	0.07186804576876543
#   (0, 15)	0.47165885524093315
#   (0, 16)	0.9313850403275804
#   (0, 17)	-0.6198787469683937
#   (0, 18)	-0.1628335520579516
#   (0, 19)	-0.2775290677669772
#   (0, 20)	-0.42821414846758676
#   (0, 21)	0.5606452304572039
#   (0, 22)	0.35702964529580145
#   (0, 23)	0.043713211343164644
#   (0, 24)	0.02988162338811878
#   :	:
#   (1030, 25)	-0.00750581964469499
#   (1030, 26)	-0.22387229812053128
#   (1030, 27)	-1.305309207259872
#   (1030, 28)	1.0234569464656569
#   (1030, 29)	-0.4278811309999175
#   (1030, 30)	1.30883703875867
#   (1030, 31)	-1.4757429600184877
#   (1030, 32)	0.423137070548714
#   (1030, 33)	0.9629503983820064
#   (1030, 34)	1.0283872078811234
#   (1030, 35)	-0.9534047826220684
#   (1030, 36)	-0.2806957802687384
#   (1030, 37)	0.2607793166676934
#   (1030, 38)	-0.7808462721683672
#   (1030, 39)	-0.214818941809998
#   (1030, 40)	-0.08596879990901693
#   (1030, 41)	0.35672712138137874
#   (1030, 42)	0.3506737281861968
#   (1030, 43)	-1.0666493088648348
#   (1030, 44)	-2.0821497971714495
#   (1030, 62)	1.0
#   (1030, 94)	1.0
#   (1030, 146)	1.0
#   (1030, 194)	1.0
#   (1030, 250)	1.0
# ...Done.
#   (0, 0)	-0.03834271189808886
#   (0, 1)	0.7518290617924952
#   (0, 2)	-2.3439275634157872
#   (0, 3)	-1.470415014097908
#   (0, 4)	-0.21739809590675968
#   (0, 5)	0.693627686875634
#   (0, 6)	-0.12862282471574757
#   (0, 7)	-0.591271746491325
#   (0, 8)	-1.272350630929766
#   (0, 9)	-0.22548028197690959
#   (0, 10)	-0.1298722676435955
#   (0, 11)	-0.5914285580153164
#   (0, 12)	-1.2097611110445048
#   (0, 13)	1.8338472681773395
#   (0, 14)	0.07186804576876543
#   (0, 15)	0.47165885524093315
#   (0, 16)	0.9313850403275804
#   (0, 17)	-0.6198787469683937
#   (0, 18)	-0.1628335520579516
#   (0, 19)	-0.2775290677669772
#   (0, 20)	-0.42821414846758676
#   (0, 21)	0.5606452304572039
#   (0, 22)	0.35702964529580145
#   (0, 23)	0.043713211343164644
#   (0, 24)	0.02988162338811878
#   :	:
#   (4, 25)	2.015808991243809
#   (4, 26)	1.6100271374637787
#   (4, 27)	0.04934565939497258
#   (4, 28)	-0.6335350095758819
#   (4, 29)	-0.4278811309999175
#   (4, 30)	-0.6157727640307705
#   (4, 31)	-0.42463602126692196
#   (4, 32)	0.423137070548714
#   (4, 33)	-0.4930925632465504
#   (4, 34)	-0.644076417392676
#   (4, 35)	-0.8400678456181552
#   (4, 36)	-0.2806957802687384
#   (4, 37)	1.1393906344728242
#   (4, 38)	0.390360837833651
#   (4, 39)	-0.23411370833923942
#   (4, 40)	-0.21828865013507642
#   (4, 41)	0.5277908969194425
#   (4, 42)	-0.12255220605459993
#   (4, 43)	0.30727940006548643
#   (4, 44)	-2.0821497971714495
#   (4, 47)	1.0
#   (4, 104)	1.0
#   (4, 149)	1.0
#   (4, 221)	1.0
#   (4, 260)	1.0
#
# Encoding labels...
# 642     1
# 1008    0
# 280     1
# 1200    1
# 1183    1
# Name: winner_home, dtype: int64
# ...Done
# [1 0 1 1 1]
# Performing preprocessings on test set...
#      season  week  awayteam   hometeam       home_coach     away_coach  \
# 745    2019     9    Texans    Jaguars     Doug Marrone   Bill O'Brien
# 432    2018     4  Seahawks  Cardinals      Steve Wilks   Pete Carroll
# 678    2019     4  Seahawks  Cardinals  Kliff Kingsbury   Pete Carroll
# 289    2018    10   Cowboys     Eagles    Doug Pederson  Jason Garrett
# 1      2017     9   Falcons   Panthers       Ron Rivera      Dan Quinn
#
#     weather_type  temperature  humidity  wind  ...  kicks_return_td_MA_5_home  \
# 745       cloudy         53.0      54.0   6.0  ...                        0.0
# 432       indoor          NaN       NaN   NaN  ...                        0.0
# 678       indoor          NaN       NaN   NaN  ...                        0.0
# 289          NaN         38.0      62.0   5.0  ...                        0.0
# 1         cloudy         61.0      86.0   4.0  ...                        0.0
#
#      punt_return_yds_MA_5_home  kicking_pts_MA_5_home  delta_day_away  \
# 745                       12.4                   10.6             6.0
# 432                       15.2                    4.2             6.0
# 678                       23.6                    6.4             6.0
# 289                       20.6                    7.8             6.0
# 1                         22.4                    7.4             7.0
#
#      delta_day_home                    stade  people  month  dayofmonth  \
# 745             6.0          Wembley Stadium    99.0     11           3
# 432             6.0       State Farm Stadium    95.0      9          30
# 678             7.0       State Farm Stadium    93.0      9          29
# 289            14.0  Lincoln Financial Field   100.0     11          12
# 1               7.0  Bank of America Stadium   100.0     11           5
#
#      dayofweek
# 745          6
# 432          6
# 678          6
# 289          0
# 1            6
#
# [5 rows x 51 columns]
# c:\Users\sylva\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:188: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...Done.
#   (0, 0)	-0.03834271189808886
#   (0, 1)	-0.040338299176398446
#   (0, 2)	-0.14802548401889187
#   (0, 3)	-0.2942177847786325
#   (0, 4)	-0.1280495365176966
#   (0, 5)	0.36213626027378715
#   (0, 6)	0.9857671482193667
#   (0, 7)	0.7260803077114376
#   (0, 8)	1.1384131354925013
#   (0, 9)	0.6910193124378573
#   (0, 10)	0.9926243600872926
#   (0, 11)	0.7301760159383414
#   (0, 12)	0.7330262317943376
#   (0, 13)	0.8598579840932894
#   (0, 14)	-1.2214824725508155
#   (0, 15)	0.47165885524093315
#   (0, 16)	-0.9483283743945345
#   (0, 17)	1.0646908737555119
#   (0, 18)	-1.001976875381956
#   (0, 19)	-0.2775290677669772
#   (0, 20)	0.3017315167618678
#   (0, 21)	0.5606452304572039
#   (0, 22)	0.669352969789346
#   (0, 23)	0.1818883204821579
#   (0, 24)	0.02988162338811878
#   :	:
#   (4, 25)	-0.8437097267277661
#   (4, 26)	-0.6823471570166089
#   (4, 27)	0.13581299130911145
#   (4, 28)	0.029261772840733696
#   (4, 29)	-0.4278811309999175
#   (4, 30)	-0.13462031333341043
#   (4, 31)	1.9403545909241002
#   (4, 32)	-0.8121077937860411
#   (4, 33)	-0.9784402171227359
#   (4, 34)	-0.644076417392676
#   (4, 35)	0.5313090921291962
#   (4, 36)	-0.2806957802687384
#   (4, 37)	0.9494206198122551
#   (4, 38)	0.27324012683344956
#   (4, 39)	-0.23411370833923942
#   (4, 40)	-0.23719148588165634
#   (4, 41)	0.5277908969194425
#   (4, 42)	0.3506737281861968
#   (4, 43)	-1.2956374270198883
#   (4, 44)	0.47831828594372783
#   (4, 58)	1.0
#   (4, 95)	1.0
#   (4, 158)	1.0
#   (4, 181)	1.0
#   (4, 238)	1.0
#
# Encoding labels...
# 745    0
# 432    0
# 678    0
# 289    0
# 1      1
# Name: winner_home, dtype: int64
# ...Done
# [0 0 0 0 1]
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=2, max_leaves=0, min_child_weight=3,
#               missing=nan, monotone_constraints='()', n_estimators=140,
#               n_jobs=-1, nthread=-1, num_parallel_tree=1, predictor='auto',
#               random_state=42, reg_alpha=0, ...)

# %% [markdown]
# Preprocessing with awayteam and hometeam

# %% [markdown]
# Logistic Regression

# %%
df_ma = pd.read_csv("../../04_datasets/nfl_team_topredict.csv", index_col=0)
df_ma
# Out:
#                           index  Unnamed: 0     idgame        team  \
# 80    2022-01-09 21:25:00+00:00        2538  401326599       49ers
# 161   2022-01-09 18:00:00+00:00        2527  401326593       Bears
# 241   2022-01-09 18:00:00+00:00        2517  401326588     Bengals
# 322   2022-01-09 21:25:00+00:00        2515  401326587       Bills
# 402   2022-01-08 21:30:00+00:00        2536  401326598     Broncos
# 482   2022-01-09 18:00:00+00:00        2518  401326588      Browns
# 563   2022-01-09 21:25:00+00:00        2532  401326596  Buccaneers
# 643   2022-01-09 21:25:00+00:00        2534  401326597   Cardinals
# 723   2022-01-10 01:20:00+00:00        2540  401326600    Chargers
# 804   2022-01-08 21:30:00+00:00        2537  401326598      Chiefs
# 885   2022-01-09 18:00:00+00:00        2523  401326591       Colts
# 966   2022-01-09 01:15:00+00:00        2530  401326595     Cowboys
# 1047  2022-01-09 21:25:00+00:00        2525  401326592    Dolphins
# 1127  2022-01-09 01:15:00+00:00        2531  401326595      Eagles
# 1208  2022-01-09 21:25:00+00:00        2511  401326585     Falcons
# 1288  2022-01-02 18:00:00+00:00        2482  401326570      Giants
# 1368  2022-01-09 18:00:00+00:00        2524  401326591     Jaguars
# 1449  2022-01-09 21:25:00+00:00        2516  401326587        Jets
# 1528  2022-01-09 18:00:00+00:00        2519  401326589       Lions
# 1608  2022-01-09 18:00:00+00:00        2520  401326589     Packers
# 1689  2022-01-09 21:25:00+00:00        2533  401326596    Panthers
# 1769  2022-01-09 21:25:00+00:00        2526  401326592    Patriots
# 1850  2022-01-10 01:20:00+00:00        2541  401326600     Raiders
# 1931  2022-01-09 21:25:00+00:00        2539  401326599        Rams
# 2012  2022-01-09 18:00:00+00:00        2513  401326586      Ravens
# 2092  2022-01-09 21:25:00+00:00        2512  401326585      Saints
# 2173  2022-01-09 21:25:00+00:00        2535  401326597    Seahawks
# 2251  2022-01-09 18:00:00+00:00        2514  401326586    Steelers
# 2332  2022-01-09 18:00:00+00:00        2521  401326590      Texans
# 2413  2022-01-09 18:00:00+00:00        2522  401326590      Titans
# 2492  2022-01-09 18:00:00+00:00        2528  401326593     Vikings
# 2541  2022-01-09 18:00:00+00:00        2529  401326594  Washington
#
#       pass_completion  pass_yds  pass_avg  pass_td  pass_int     sacks  ...  \
# 80           1.718750     340.0      33.9      2.0       2.0  0.115385  ...
# 161          0.687500     325.0       6.8      1.0       2.0  0.118644  ...
# 241          0.517241     136.0       4.7      1.0       0.0  0.121212  ...
# 322          1.533333     254.0      20.3      2.0       0.0  0.000000  ...
# 402          1.500000     178.0      22.8      0.0       0.0  0.200000  ...
# 482          0.708333     176.0       7.3      2.0       1.0  0.200000  ...
# 563          0.783784     326.0       8.8      3.0       0.0  0.500000  ...
# 643          0.717949     240.0       6.2      1.0       0.0  0.094340  ...
# 723          0.531250     383.0       6.0      3.0       1.0  0.107143  ...
# 804          0.613636     270.0       6.1      2.0       0.0  0.066667  ...
# 885          0.586207     185.0       6.4      1.0       1.0  0.130435  ...
# 966          1.777778     305.0      20.9      5.0       0.0  1.000000  ...
# 1047         0.681818     109.0       5.0      1.0       0.0  0.166667  ...
# 1127         1.575758     188.0       7.6      2.0       1.0  0.136364  ...
# 1208         0.000000       0.0       0.0      0.0       0.0  0.000000  ...
# 1288         0.363636      24.0       2.2      0.0       2.0  0.133333  ...
# 1368         0.718750     223.0       7.0      2.0       0.0  0.166667  ...
# 1449         0.350000      87.0       4.4      1.0       0.0  0.434599  ...
# 1528         1.700000     313.0      82.9      3.0       0.0  0.125000  ...
# 1608         1.366013     272.0      15.6      3.0       2.0  0.500000  ...
# 1689         0.690476     219.0       5.2      2.0       1.0  0.166667  ...
# 1769         0.666667     261.0       8.7      1.0       1.0  0.125000  ...
# 1850         1.555556     190.0       9.2      2.0       0.0  0.166667  ...
# 1931         0.656250     238.0       7.4      3.0       2.0  0.135135  ...
# 2012         0.516129     141.0       4.5      0.0       2.0  0.333333  ...
# 2092         1.377778     178.0      16.6      3.0       0.0  0.250000  ...
# 2173         0.576923     238.0       9.2      3.0       1.0  0.111111  ...
# 2251         0.681818     244.0       5.5      1.0       1.0  0.111111  ...
# 2332         0.696970     301.0       9.1      3.0       0.0  0.166667  ...
# 2413         0.718750     287.0       9.0      4.0       0.0  0.166667  ...
# 2492         0.636364     250.0      11.4      3.0       0.0  0.130435  ...
# 2541         0.000000       0.0       0.0      0.0       0.0  0.000000  ...
#
#       punt_return_td_MA_5  kicking_pct_MA_5  kicking_long_MA_5  \
# 80                    0.0              93.4               38.0
# 161                   0.2              90.0               40.6
# 241                   0.0              73.4               35.2
# 322                   0.0              80.0               25.2
# 402                   0.0              83.4               50.6
# 482                   0.0              30.0               16.0
# 563                   0.0              73.4               30.2
# 643                   0.0              86.6               40.8
# 723                   0.0              70.0               30.6
# 804                   0.0              95.0               43.2
# 885                   0.0              76.8               38.4
# 966                   0.0              60.0               25.6
# 1047                  0.0              76.8               41.6
# 1127                  0.0              93.4               40.4
# 1208                  0.0              80.0               35.4
# 1288                  0.0              75.0               37.0
# 1368                  0.0              80.0               30.2
# 1449                  0.0              80.0               33.8
# 1528                  0.0              80.0               31.2
# 1608                  0.0             100.0               30.8
# 1689                  0.0              50.0               19.2
# 1769                  0.0              80.0               30.4
# 1850                  0.0             100.0               42.8
# 1931                  0.2              80.0               37.0
# 2012                  0.0              80.0               37.0
# 2092                  0.0              95.0               39.0
# 2173                  0.0              90.0               40.4
# 2251                  0.0              66.0               34.4
# 2332                  0.0              73.4               39.0
# 2413                  0.0              53.4               24.0
# 2492                  0.0              95.0               42.6
# 2541                  0.0              40.0               15.4
#
#       kicking_pts_MA_5  punting_no_MA_5  punting_yds_MA_5  punting_avg_MA_5  \
# 80                 8.0              4.2             178.2             50.58
# 161                7.6              3.2             150.2             46.68
# 241                6.8              3.4             159.4             27.26
# 322                7.4              3.6             142.2             23.84
# 402                6.4              4.0             188.8             46.68
# 482                3.4              5.0             207.6             40.24
# 563                8.4              4.4             178.4             40.24
# 643                9.2              2.2              99.6             45.32
# 723                8.4              2.0              79.2             31.86
# 804                9.4              1.8              76.8             43.20
# 885                7.0              3.0             125.4             41.34
# 966                8.2              3.8             176.2             46.20
# 1047               7.0              4.6             212.0             46.58
# 1127              10.0              2.4              88.8             36.80
# 1208               6.6              2.0              96.6             40.36
# 1288               4.6              5.0             205.4             42.64
# 1368               7.4              3.6             166.4             48.38
# 1449               4.8              4.2             197.0             37.94
# 1528               8.4              2.4             115.4             48.86
# 1608               7.8              3.0             130.0             41.00
# 1689               3.6              3.6             168.4             45.82
# 1769               5.6              3.0             133.6             44.14
# 1850               9.2              3.0             139.4             46.82
# 1931               8.0              2.8             129.6             46.56
# 2012               7.8              3.8             162.0             43.30
# 2092               9.6              5.6             260.2             47.10
# 2173               8.0              3.4             147.4             42.56
# 2251               8.6              5.2             224.0             45.88
# 2332               7.2              4.4             203.2             47.32
# 2413               5.4              3.4             152.4             36.28
# 2492               7.8              5.4             247.0             46.12
# 2541               3.4              4.0             197.6             38.44
#
#       punting_tb_MA_5  punting_in_20_MA_5  punting_long_MA_5
# 80                0.2                 1.0               58.4
# 161               0.6                 0.6               57.8
# 241               0.2                 0.8               33.8
# 322               0.2                 1.4               31.8
# 402               0.2                 1.6               57.4
# 482               0.4                 1.2               48.4
# 563               0.0                 1.4               47.6
# 643               0.0                 0.4               48.8
# 723               0.0                 0.4               36.6
# 804               0.4                 0.4               46.8
# 885               0.0                 1.4               46.6
# 966               0.2                 1.6               54.4
# 1047              0.0                 2.0               54.6
# 1127              0.2                 0.8               42.2
# 1208              0.2                 0.8               45.2
# 1288              0.6                 1.6               50.8
# 1368              0.2                 0.8               54.2
# 1449              0.0                 1.8               44.8
# 1528              0.0                 0.4               58.0
# 1608              0.4                 0.6               49.2
# 1689              0.0                 1.2               56.0
# 1769              0.4                 0.8               53.4
# 1850              0.4                 1.2               54.0
# 1931              0.0                 1.4               52.0
# 2012              0.0                 1.4               52.0
# 2092              0.2                 2.2               57.8
# 2173              0.4                 1.6               46.8
# 2251              0.2                 1.2               53.0
# 2332              0.4                 1.8               53.8
# 2413              0.2                 1.0               42.4
# 2492              0.2                 1.6               59.2
# 2541              0.4                 1.4               44.2
#
# [32 rows x 107 columns]

# %%
df_games = pd.read_csv("../../04_datasets/nfl2022_total.csv", index_col=0)
df_games
# Out:
#      season  week        date   awayteam    hometeam  \
# 0      2022     5  2022-10-06      Colts     Broncos
# 1      2022     5  2022-10-09     Giants     Packers
# 2      2022     5  2022-10-09   Steelers       Bills
# 3      2022     5  2022-10-09   Chargers      Browns
# 4      2022     5  2022-10-09      Bears     Vikings
# ..      ...   ...         ...        ...         ...
# 267    2022    18  2023-01-08     Browns    Steelers
# 268    2022    18  2023-01-08  Cardinals       49ers
# 269    2022    18  2023-01-08       Rams    Seahawks
# 270    2022    18  2023-01-08    Cowboys  Washington
# 271    2022    18  2023-01-08     Titans     Jaguars
#
#                         stadium          location
# 0    Empower Field at Mile High        Denver, CO
# 1     Tottenham Hotspur Stadium            London
# 2              Highmark Stadium  Orchard Park, NY
# 3           FirstEnergy Stadium     Cleveland, OH
# 4             U.S. Bank Stadium   Minneapolis, MN
# ..                          ...               ...
# 267            Acrisure Stadium    Pittsburgh, PA
# 268              Levi's Stadium   Santa Clara, CA
# 269                 Lumen Field       Seattle, WA
# 270                  FedExField      Landover, MD
# 271             TIAA Bank Field  Jacksonville, FL
#
# [272 rows x 7 columns]

# %%
df_games.columns
# Out:
# Index(['season', 'week', 'date', 'awayteam', 'hometeam', 'stadium',
#        'location'],
#       dtype='object')

# %%
dataset.columns
# Out:
# Index(['season', 'week', 'awayteam', 'hometeam', 'idgame', 'winner_home',
#        'home_coach', 'away_coach', 'weather_type', 'temperature', 'humidity',
#        'wind', 'streak_away', 'pass_yds_MA_5_away', 'pass_td_MA_5_away',
#        'rush_yds_MA_5_away', 'rush_td_MA_5_away', 'rec_yds_MA_5_away',
#        'rec_td_MA_5_away', 'fumbles_MA_5_away', 'fumbles_rec_MA_5_away',
#        'defense_sacks_MA_5_away', 'defense_td_MA_5_away',
#        'interceptions_MA_5_away', 'interceptions_td_MA_5_away',
#        'kicks_return_yds_MA_5_away', 'kicks_return_td_MA_5_away',
#        'punt_return_yds_MA_5_away', 'kicking_pts_MA_5_away', 'streak_home',
#        'pass_yds_MA_5_home', 'pass_td_MA_5_home', 'rush_yds_MA_5_home',
#        'rush_td_MA_5_home', 'rec_yds_MA_5_home', 'rec_td_MA_5_home',
#        'fumbles_MA_5_home', 'fumbles_rec_MA_5_home', 'defense_sacks_MA_5_home',
#        'defense_td_MA_5_home', 'interceptions_MA_5_home',
#        'interceptions_td_MA_5_home', 'kicks_return_yds_MA_5_home',
#        'kicks_return_td_MA_5_home', 'punt_return_yds_MA_5_home',
#        'kicking_pts_MA_5_home', 'delta_day_away', 'delta_day_home', 'stade',
#        'location', 'people', 'month', 'dayofmonth', 'dayofweek'],
#       dtype='object')

# %%
df_games_topredict = pd.DataFrame(columns = [col for col in dataset.columns])

# %%
df_games_topredict.columns
# Out:
# Index(['season', 'week', 'awayteam', 'hometeam', 'idgame', 'winner_home',
#        'home_coach', 'away_coach', 'weather_type', 'temperature', 'humidity',
#        'wind', 'streak_away', 'pass_yds_MA_5_away', 'pass_td_MA_5_away',
#        'rush_yds_MA_5_away', 'rush_td_MA_5_away', 'rec_yds_MA_5_away',
#        'rec_td_MA_5_away', 'fumbles_MA_5_away', 'fumbles_rec_MA_5_away',
#        'defense_sacks_MA_5_away', 'defense_td_MA_5_away',
#        'interceptions_MA_5_away', 'interceptions_td_MA_5_away',
#        'kicks_return_yds_MA_5_away', 'kicks_return_td_MA_5_away',
#        'punt_return_yds_MA_5_away', 'kicking_pts_MA_5_away', 'streak_home',
#        'pass_yds_MA_5_home', 'pass_td_MA_5_home', 'rush_yds_MA_5_home',
#        'rush_td_MA_5_home', 'rec_yds_MA_5_home', 'rec_td_MA_5_home',
#        'fumbles_MA_5_home', 'fumbles_rec_MA_5_home', 'defense_sacks_MA_5_home',
#        'defense_td_MA_5_home', 'interceptions_MA_5_home',
#        'interceptions_td_MA_5_home', 'kicks_return_yds_MA_5_home',
#        'kicks_return_td_MA_5_home', 'punt_return_yds_MA_5_home',
#        'kicking_pts_MA_5_home', 'delta_day_away', 'delta_day_home', 'stade',
#        'location', 'people', 'month', 'dayofmonth', 'dayofweek'],
#       dtype='object')

# %%
df_games_topredict = pd.concat([df_games, df_games_topredict])

# %%
df_games_topredict.columns
# Out:
# Index(['season', 'week', 'date', 'awayteam', 'hometeam', 'stadium', 'location',
#        'idgame', 'winner_home', 'home_coach', 'away_coach', 'weather_type',
#        'temperature', 'humidity', 'wind', 'streak_away', 'pass_yds_MA_5_away',
#        'pass_td_MA_5_away', 'rush_yds_MA_5_away', 'rush_td_MA_5_away',
#        'rec_yds_MA_5_away', 'rec_td_MA_5_away', 'fumbles_MA_5_away',
#        'fumbles_rec_MA_5_away', 'defense_sacks_MA_5_away',
#        'defense_td_MA_5_away', 'interceptions_MA_5_away',
#        'interceptions_td_MA_5_away', 'kicks_return_yds_MA_5_away',
#        'kicks_return_td_MA_5_away', 'punt_return_yds_MA_5_away',
#        'kicking_pts_MA_5_away', 'streak_home', 'pass_yds_MA_5_home',
#        'pass_td_MA_5_home', 'rush_yds_MA_5_home', 'rush_td_MA_5_home',
#        'rec_yds_MA_5_home', 'rec_td_MA_5_home', 'fumbles_MA_5_home',
#        'fumbles_rec_MA_5_home', 'defense_sacks_MA_5_home',
#        'defense_td_MA_5_home', 'interceptions_MA_5_home',
#        'interceptions_td_MA_5_home', 'kicks_return_yds_MA_5_home',
#        'kicks_return_td_MA_5_home', 'punt_return_yds_MA_5_home',
#        'kicking_pts_MA_5_home', 'delta_day_away', 'delta_day_home', 'stade',
#        'people', 'month', 'dayofmonth', 'dayofweek'],
#       dtype='object')

# %%
df_games_topredict
# Out:
#     season week        date   awayteam    hometeam  \
# 0     2022    5  2022-10-06      Colts     Broncos
# 1     2022    5  2022-10-09     Giants     Packers
# 2     2022    5  2022-10-09   Steelers       Bills
# 3     2022    5  2022-10-09   Chargers      Browns
# 4     2022    5  2022-10-09      Bears     Vikings
# ..     ...  ...         ...        ...         ...
# 267   2022   18  2023-01-08     Browns    Steelers
# 268   2022   18  2023-01-08  Cardinals       49ers
# 269   2022   18  2023-01-08       Rams    Seahawks
# 270   2022   18  2023-01-08    Cowboys  Washington
# 271   2022   18  2023-01-08     Titans     Jaguars
#
#                         stadium          location idgame winner_home  \
# 0    Empower Field at Mile High        Denver, CO    NaN         NaN
# 1     Tottenham Hotspur Stadium            London    NaN         NaN
# 2              Highmark Stadium  Orchard Park, NY    NaN         NaN
# 3           FirstEnergy Stadium     Cleveland, OH    NaN         NaN
# 4             U.S. Bank Stadium   Minneapolis, MN    NaN         NaN
# ..                          ...               ...    ...         ...
# 267            Acrisure Stadium    Pittsburgh, PA    NaN         NaN
# 268              Levi's Stadium   Santa Clara, CA    NaN         NaN
# 269                 Lumen Field       Seattle, WA    NaN         NaN
# 270                  FedExField      Landover, MD    NaN         NaN
# 271             TIAA Bank Field  Jacksonville, FL    NaN         NaN
#
#     home_coach  ... kicks_return_td_MA_5_home punt_return_yds_MA_5_home  \
# 0          NaN  ...                       NaN                       NaN
# 1          NaN  ...                       NaN                       NaN
# 2          NaN  ...                       NaN                       NaN
# 3          NaN  ...                       NaN                       NaN
# 4          NaN  ...                       NaN                       NaN
# ..         ...  ...                       ...                       ...
# 267        NaN  ...                       NaN                       NaN
# 268        NaN  ...                       NaN                       NaN
# 269        NaN  ...                       NaN                       NaN
# 270        NaN  ...                       NaN                       NaN
# 271        NaN  ...                       NaN                       NaN
#
#     kicking_pts_MA_5_home delta_day_away delta_day_home stade people month  \
# 0                     NaN            NaN            NaN   NaN    NaN   NaN
# 1                     NaN            NaN            NaN   NaN    NaN   NaN
# 2                     NaN            NaN            NaN   NaN    NaN   NaN
# 3                     NaN            NaN            NaN   NaN    NaN   NaN
# 4                     NaN            NaN            NaN   NaN    NaN   NaN
# ..                    ...            ...            ...   ...    ...   ...
# 267                   NaN            NaN            NaN   NaN    NaN   NaN
# 268                   NaN            NaN            NaN   NaN    NaN   NaN
# 269                   NaN            NaN            NaN   NaN    NaN   NaN
# 270                   NaN            NaN            NaN   NaN    NaN   NaN
# 271                   NaN            NaN            NaN   NaN    NaN   NaN
#
#     dayofmonth dayofweek
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# ..         ...       ...
# 267        NaN       NaN
# 268        NaN       NaN
# 269        NaN       NaN
# 270        NaN       NaN
# 271        NaN       NaN
#
# [272 rows x 56 columns]

# %%
df_games_topredict = preprocessor.transform(df_games_topredict)
Y_pred = model.predict(df_games_topredict)

# %%
Y_pred = pd.DataFrame(Y_pred, columns = ["winner"] )

# %%
Y_pred
# Out:
#      winner
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 267       0
# 268       0
# 269       0
# 270       0
# 271       0
#
# [272 rows x 1 columns]

# %%
Y_pred_proba = model.predict_proba(df_games_topredict).round(4)

# %%
Y_pred_proba
# Out:
# array([[0.597 , 0.403 ],
#        [0.508 , 0.492 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5864, 0.4136],
#        [0.6059, 0.3941],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.7391, 0.2609],
#        [0.5926, 0.4074],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.4665, 0.5335],
#        [0.5836, 0.4164],
#        [0.597 , 0.403 ],
#        [0.6134, 0.3866],
#        [0.597 , 0.403 ],
#        [0.5041, 0.4959],
#        [0.4555, 0.5445],
#        [0.597 , 0.403 ],
#        [0.4757, 0.5243],
#        [0.6159, 0.3841],
#        [0.5188, 0.4812],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5836, 0.4164],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5836, 0.4164],
#        [0.5634, 0.4366],
#        [0.597 , 0.403 ],
#        [0.6059, 0.3941],
#        [0.6159, 0.3841],
#        [0.5188, 0.4812],
#        [0.7391, 0.2609],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.4665, 0.5335],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5385, 0.4615],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.7724, 0.2276],
#        [0.597 , 0.403 ],
#        [0.5836, 0.4164],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5926, 0.4074],
#        [0.7149, 0.2851],
#        [0.597 , 0.403 ],
#        [0.5634, 0.4366],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.7309, 0.2691],
#        [0.597 , 0.403 ],
#        [0.5998, 0.4002],
#        [0.597 , 0.403 ],
#        [0.6059, 0.3941],
#        [0.6134, 0.3866],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.6159, 0.3841],
#        [0.4555, 0.5445],
#        [0.4844, 0.5156],
#        [0.597 , 0.403 ],
#        [0.6382, 0.3618],
#        [0.5926, 0.4074],
#        [0.5385, 0.4615],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.7391, 0.2609],
#        [0.6134, 0.3866],
#        [0.7309, 0.2691],
#        [0.6688, 0.3312],
#        [0.597 , 0.403 ],
#        [0.7843, 0.2157],
#        [0.597 , 0.403 ],
#        [0.7309, 0.2691],
#        [0.597 , 0.403 ],
#        [0.5836, 0.4164],
#        [0.5998, 0.4002],
#        [0.4665, 0.5335],
#        [0.597 , 0.403 ],
#        [0.7692, 0.2308],
#        [0.4555, 0.5445],
#        [0.6688, 0.3312],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.6059, 0.3941],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.6382, 0.3618],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5673, 0.4327],
#        [0.597 , 0.403 ],
#        [0.4665, 0.5335],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.4555, 0.5445],
#        [0.5926, 0.4074],
#        [0.6382, 0.3618],
#        [0.5673, 0.4327],
#        [0.597 , 0.403 ],
#        [0.7309, 0.2691],
#        [0.597 , 0.403 ],
#        [0.6159, 0.3841],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.6382, 0.3618],
#        [0.6134, 0.3866],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5998, 0.4002],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.7391, 0.2609],
#        [0.597 , 0.403 ],
#        [0.6688, 0.3312],
#        [0.5836, 0.4164],
#        [0.6059, 0.3941],
#        [0.5926, 0.4074],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5836, 0.4164],
#        [0.597 , 0.403 ],
#        [0.4418, 0.5582],
#        [0.597 , 0.403 ],
#        [0.6159, 0.3841],
#        [0.7118, 0.2882],
#        [0.597 , 0.403 ],
#        [0.5385, 0.4615],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5385, 0.4615],
#        [0.6134, 0.3866],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5663, 0.4337],
#        [0.677 , 0.323 ],
#        [0.6027, 0.3973],
#        [0.597 , 0.403 ],
#        [0.6382, 0.3618],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.7309, 0.2691],
#        [0.3889, 0.6111],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5634, 0.4366],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.4555, 0.5445],
#        [0.6159, 0.3841],
#        [0.5188, 0.4812],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.7309, 0.2691],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.6059, 0.3941],
#        [0.5673, 0.4327],
#        [0.597 , 0.403 ],
#        [0.5836, 0.4164],
#        [0.5926, 0.4074],
#        [0.7391, 0.2609],
#        [0.7639, 0.2361],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.4665, 0.5335],
#        [0.597 , 0.403 ],
#        [0.614 , 0.386 ],
#        [0.4555, 0.5445],
#        [0.597 , 0.403 ],
#        [0.7724, 0.2276],
#        [0.597 , 0.403 ],
#        [0.5836, 0.4164],
#        [0.5673, 0.4327],
#        [0.4694, 0.5306],
#        [0.5791, 0.4209],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5188, 0.4812],
#        [0.597 , 0.403 ],
#        [0.5673, 0.4327],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.4665, 0.5335],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5926, 0.4074],
#        [0.7391, 0.2609],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.6565, 0.3435],
#        [0.7724, 0.2276],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5998, 0.4002],
#        [0.6134, 0.3866],
#        [0.597 , 0.403 ],
#        [0.4555, 0.5445],
#        [0.5634, 0.4366],
#        [0.6159, 0.3841],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.6382, 0.3618],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.7309, 0.2691],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.7724, 0.2276],
#        [0.597 , 0.403 ],
#        [0.6134, 0.3866],
#        [0.597 , 0.403 ],
#        [0.5836, 0.4164],
#        [0.5998, 0.4002],
#        [0.6159, 0.3841],
#        [0.7724, 0.2276],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.4837, 0.5163],
#        [0.597 , 0.403 ],
#        [0.5634, 0.4366],
#        [0.5385, 0.4615],
#        [0.6688, 0.3312],
#        [0.597 , 0.403 ],
#        [0.6134, 0.3866],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.597 , 0.403 ],
#        [0.5246, 0.4754],
#        [0.597 , 0.403 ],
#        [0.7309, 0.2691],
#        [0.5634, 0.4366],
#        [0.6059, 0.3941],
#        [0.5673, 0.4327],
#        [0.5188, 0.4812],
#        [0.597 , 0.403 ],
#        [0.6688, 0.3312],
#        [0.597 , 0.403 ],
#        [0.7391, 0.2609]], dtype=float32)

# %%
Y_pred_proba = pd.DataFrame(Y_pred_proba, columns=["proba_away", "proba_home"])

# %%
Y_pred_proba
# Out:
#      proba_away  proba_home
# 0        0.5970      0.4030
# 1        0.5080      0.4920
# 2        0.5970      0.4030
# 3        0.5970      0.4030
# 4        0.5970      0.4030
# ..          ...         ...
# 267      0.5188      0.4812
# 268      0.5970      0.4030
# 269      0.6688      0.3312
# 270      0.5970      0.4030
# 271      0.7391      0.2609
#
# [272 rows x 2 columns]

# %%
res = pd.concat([df_games,Y_pred], axis =1)

# %%
res =pd.concat([res,Y_pred_proba], axis = 1)

# %%
res["winner"].value_counts()
# Out:
# 0    253
# 1     19
# Name: winner, dtype: int64

# %%
os.getcwd()
# Out:
# 'c:\\Users\\sylva\\Desktop\\nflpredictor\\nfl\\03_modelisation\\03_model3_XGBoost'

# %%
res.to_csv("05_results/results_games_2022_xgb.csv")
