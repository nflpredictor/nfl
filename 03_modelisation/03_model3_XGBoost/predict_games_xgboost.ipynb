# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import  OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
# import ensemble methods
from xgboost import XGBClassifier
# import base estimators
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, ConfusionMatrixDisplay, RocCurveDisplay

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) # to avoid deprecation warnings

# %%
os.getcwd()
# Out:
# 'c:\\Users\\sylva\\Desktop\\nflpredictor\\nfl\\03_modelisation\\03_model3_XGBoost'

# %% [markdown]
# # Import dataset final

# %%
# df = pd.read_csv("../../04_datasets/nfl_dataset_vf.csv", index_col=0)
dataset = pd.read_csv("../../04_datasets/nfl_dataset_vf.csv", index_col=0)

# %% [markdown]
# # preprocessing and modelisation

# %%
# Separate target variable Y from features X
print("Separating labels from features...")
target_variable = "winner_home"

X = dataset.drop(target_variable, axis = 1)
features_drop_list = {'idgame', 'location'}
X.drop(features_drop_list, axis=1, inplace=True)

Y = dataset.loc[:,target_variable]

# Automatically detect names of numeric/categorical columns
numeric_features = []
categorical_features = []
for i,t in X.dtypes.iteritems():
    if ('float' in str(t)) or ('int' in str(t)) :
        numeric_features.append(i)
    else :
        categorical_features.append(i)

# print('Found numeric features ', numeric_features)
# print('Found categorical features ', categorical_features)

# print("Dividing into train and test sets...")
# WARNING : don't forget stratify=Y for classification problems
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0, stratify = Y)


# Create pipeline for numeric features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')), # missing values will be replaced by columns' mean
    ('scaler', StandardScaler())
])

# Create pipeline for categorical features
#categorical_transformer = OneHotEncoder(drop='first') # no missing values in categorical data, so we only need the OHE

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')), # missing values will be replaced by most frequent value
    ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore')) # first column will be dropped to avoid creating correlations between features
    ])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Preprocessings on train set
# print("Performing preprocessings on train set...")
# print(X_train.head())
X_train = preprocessor.fit_transform(X_train)
# print('...Done preprocessing train set.')
# print(X_train)
# print('...Done.')
# print(X_train[0:5]) # MUST use this syntax because X_train is a numpy array and not a pandas DataFrame anymore
# print()
# Label encoding
# print("Encoding labels...")
# print(Y_train.head())
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
# print("...Done")
# print(Y_train[0:5])

# Preprocessings on test set
# print("Performing preprocessings on test set...")
# print(X_test.head()) 
X_test = preprocessor.transform(X_test) # Don't fit again !! The test set is used for validating decisions
# we made based on the training set, therefore we can only apply transformations that were parametered using the training set.
# Otherwise this creates what is called a leak from the test set which will introduce a bias in all your results.
# print('...Done.')
# print(X_test[0:5,:]) # MUST use this syntax because X_test is a numpy array and not a pandas DataFrame anymore
# print()
# Label encoding
# print("Encoding labels...")
# print(Y_test[0:5])
Y_test = encoder.transform(Y_test)
# print("...Done")
# print(Y_test[0:5])

model = XGBClassifier(
    objective= 'binary:logistic',
    nthread=-1,
    seed=42,
    learning_rate= 0.1, 
    max_depth= 2,
    min_child_weight= 3,
    n_estimators= 140
    )

model.fit(X_train, Y_train)
# Out:
# Separating labels from features...
# c:\Users\sylva\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:188: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=2, max_leaves=0, min_child_weight=3,
#               missing=nan, monotone_constraints='()', n_estimators=140,
#               n_jobs=-1, nthread=-1, num_parallel_tree=1, predictor='auto',
#               random_state=42, reg_alpha=0, ...)

# %% [markdown]
# import of calculated features

# %%
df_ma = pd.read_csv("../../04_datasets/nfl_team_topredict.csv", index_col=0)

# %% [markdown]
# import of future games

# %%
df_games = pd.read_csv("../../04_datasets/nfl2022_total.csv", index_col=0)
df_games
# Out:
#      season  week        date   awayteam    hometeam  \
# 0      2022     5  2022-10-06      Colts     Broncos
# 1      2022     5  2022-10-09     Giants     Packers
# 2      2022     5  2022-10-09   Steelers       Bills
# 3      2022     5  2022-10-09   Chargers      Browns
# 4      2022     5  2022-10-09      Bears     Vikings
# ..      ...   ...         ...        ...         ...
# 267    2022    18  2023-01-08     Browns    Steelers
# 268    2022    18  2023-01-08  Cardinals       49ers
# 269    2022    18  2023-01-08       Rams    Seahawks
# 270    2022    18  2023-01-08    Cowboys  Washington
# 271    2022    18  2023-01-08     Titans     Jaguars
#
#                         stadium          location
# 0    Empower Field at Mile High        Denver, CO
# 1     Tottenham Hotspur Stadium            London
# 2              Highmark Stadium  Orchard Park, NY
# 3           FirstEnergy Stadium     Cleveland, OH
# 4             U.S. Bank Stadium   Minneapolis, MN
# ..                          ...               ...
# 267            Acrisure Stadium    Pittsburgh, PA
# 268              Levi's Stadium   Santa Clara, CA
# 269                 Lumen Field       Seattle, WA
# 270                  FedExField      Landover, MD
# 271             TIAA Bank Field  Jacksonville, FL
#
# [272 rows x 7 columns]

# %% [markdown]
# # Create df to predict

# %%
df_games_topredict = pd.DataFrame(columns = [col for col in dataset.columns])
df_games_topredict = pd.concat([df_games, df_games_topredict])

# %%
df_games_topredict.columns
# Out:
# Index(['season', 'week', 'date', 'awayteam', 'hometeam', 'stadium', 'location',
#        'idgame', 'winner_home', 'home_coach', 'away_coach', 'weather_type',
#        'temperature', 'humidity', 'wind', 'streak_away', 'pass_yds_MA_5_away',
#        'pass_td_MA_5_away', 'rush_yds_MA_5_away', 'rush_td_MA_5_away',
#        'rec_yds_MA_5_away', 'rec_td_MA_5_away', 'fumbles_MA_5_away',
#        'fumbles_rec_MA_5_away', 'defense_sacks_MA_5_away',
#        'defense_td_MA_5_away', 'interceptions_MA_5_away',
#        'interceptions_td_MA_5_away', 'kicks_return_yds_MA_5_away',
#        'kicks_return_td_MA_5_away', 'punt_return_yds_MA_5_away',
#        'kicking_pts_MA_5_away', 'streak_home', 'pass_yds_MA_5_home',
#        'pass_td_MA_5_home', 'rush_yds_MA_5_home', 'rush_td_MA_5_home',
#        'rec_yds_MA_5_home', 'rec_td_MA_5_home', 'fumbles_MA_5_home',
#        'fumbles_rec_MA_5_home', 'defense_sacks_MA_5_home',
#        'defense_td_MA_5_home', 'interceptions_MA_5_home',
#        'interceptions_td_MA_5_home', 'kicks_return_yds_MA_5_home',
#        'kicks_return_td_MA_5_home', 'punt_return_yds_MA_5_home',
#        'kicking_pts_MA_5_home', 'delta_day_away', 'delta_day_home', 'stade',
#        'people', 'month', 'dayofmonth', 'dayofweek'],
#       dtype='object')

# %% [markdown]
# Filter week 1

# %%
df_week = df_games_topredict[df_games_topredict["week"] == 1]

# %% [markdown]
# List of columns

# %%
features_ma_home = [col for col in df_week.columns if "_MA_5_home" in col]
features_ma_away = [col for col in df_week.columns if "_MA_5_away" in col]
features_ma_topredict = [col.split("_home")[0] for col in df_week.columns if "_MA_5_home" in col]

# %%
print(len(features_ma_home))
print(len(features_ma_away))
print(len(features_ma_topredict))
# Out:
# 16
# 16

# %%
df_comp = pd.concat([pd.DataFrame(features_ma_home), 
                    pd.DataFrame(features_ma_away),
                    pd.DataFrame(features_ma_topredict)],
                    axis =1)
df_comp
# Out:
#                              0                           0  \
# 0           pass_yds_MA_5_home          pass_yds_MA_5_away
# 1            pass_td_MA_5_home           pass_td_MA_5_away
# 2           rush_yds_MA_5_home          rush_yds_MA_5_away
# 3            rush_td_MA_5_home           rush_td_MA_5_away
# 4            rec_yds_MA_5_home           rec_yds_MA_5_away
# 5             rec_td_MA_5_home            rec_td_MA_5_away
# 6            fumbles_MA_5_home           fumbles_MA_5_away
# 7        fumbles_rec_MA_5_home       fumbles_rec_MA_5_away
# 8      defense_sacks_MA_5_home     defense_sacks_MA_5_away
# 9         defense_td_MA_5_home        defense_td_MA_5_away
# 10     interceptions_MA_5_home     interceptions_MA_5_away
# 11  interceptions_td_MA_5_home  interceptions_td_MA_5_away
# 12  kicks_return_yds_MA_5_home  kicks_return_yds_MA_5_away
# 13   kicks_return_td_MA_5_home   kicks_return_td_MA_5_away
# 14   punt_return_yds_MA_5_home   punt_return_yds_MA_5_away
# 15       kicking_pts_MA_5_home       kicking_pts_MA_5_away
#
#                         0
# 0           pass_yds_MA_5
# 1            pass_td_MA_5
# 2           rush_yds_MA_5
# 3            rush_td_MA_5
# 4            rec_yds_MA_5
# 5             rec_td_MA_5
# 6            fumbles_MA_5
# 7        fumbles_rec_MA_5
# 8      defense_sacks_MA_5
# 9         defense_td_MA_5
# 10     interceptions_MA_5
# 11  interceptions_td_MA_5
# 12  kicks_return_yds_MA_5
# 13   kicks_return_td_MA_5
# 14   punt_return_yds_MA_5
# 15       kicking_pts_MA_5

# %% [markdown]
# fill in the moving averages of the home team.

# %%
for team in df_week["hometeam"].unique():
    df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# Out:
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["hometeam"] == team, features_ma_home] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\2395358065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values

# %% [markdown]
# fill in the moving averages of the away team.

# %%
for team in df_week["awayteam"].unique():
    df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# Out:
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values
# C:\Users\sylva\AppData\Local\Temp\ipykernel_7844\1195469455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_week.loc[df_week["awayteam"] == team, features_ma_away] = df_ma.loc[df_ma["team"]==team, features_ma_topredict].values

# %% [markdown]
# concat features_ma_away + features_ma_home

# %%
features_ma_away_home = features_ma_away + features_ma_home
# Out:
# ['pass_yds_MA_5_away',
#  'pass_td_MA_5_away',
#  'rush_yds_MA_5_away',
#  'rush_td_MA_5_away',
#  'rec_yds_MA_5_away',
#  'rec_td_MA_5_away',
#  'fumbles_MA_5_away',
#  'fumbles_rec_MA_5_away',
#  'defense_sacks_MA_5_away',
#  'defense_td_MA_5_away',
#  'interceptions_MA_5_away',
#  'interceptions_td_MA_5_away',
#  'kicks_return_yds_MA_5_away',
#  'kicks_return_td_MA_5_away',
#  'punt_return_yds_MA_5_away',
#  'kicking_pts_MA_5_away',
#  'pass_yds_MA_5_home',
#  'pass_td_MA_5_home',
#  'rush_yds_MA_5_home',
#  'rush_td_MA_5_home',
#  'rec_yds_MA_5_home',
#  'rec_td_MA_5_home',
#  'fumbles_MA_5_home',
#  'fumbles_rec_MA_5_home',
#  'defense_sacks_MA_5_home',
#  'defense_td_MA_5_home',
#  'interceptions_MA_5_home',
#  'interceptions_td_MA_5_home',
#  'kicks_return_yds_MA_5_home',
#  'kicks_return_td_MA_5_home',
#  'punt_return_yds_MA_5_home',
#  'kicking_pts_MA_5_home']

# %% [markdown]
# # Fill in the data for week 1

# %%
df_games_topredict.loc[df_games_topredict["week"] == 1, features_ma_away_home] = df_week.loc[:, features_ma_away_home].values

# %%
df_games_topredict = preprocessor.transform(df_games_topredict)

Y_pred = model.predict(df_games_topredict)
Y_pred = pd.DataFrame(Y_pred, columns = ["winner"] )

Y_pred_proba = model.predict_proba(df_games_topredict).round(4)
Y_pred_proba = pd.DataFrame(Y_pred_proba, columns=["proba_away", "proba_home"])

# %%
res = pd.concat([df_games,Y_pred,Y_pred_proba], axis =1)

# %%
res[res["week"]==1]
# Out:
#      season  week        date    awayteam    hometeam  \
# 81     2022     1  2022-09-08       Bills        Rams
# 82     2022     1  2022-09-11      Saints     Falcons
# 108    2022     1  2022-09-11       49ers       Bears
# 109    2022     1  2022-09-11    Steelers     Bengals
# 110    2022     1  2022-09-11      Eagles       Lions
# 111    2022     1  2022-09-11    Patriots    Dolphins
# 112    2022     1  2022-09-11      Ravens        Jets
# 113    2022     1  2022-09-11     Jaguars  Washington
# 114    2022     1  2022-09-11      Browns    Panthers
# 115    2022     1  2022-09-11       Colts      Texans
# 116    2022     1  2022-09-11      Giants      Titans
# 117    2022     1  2022-09-11     Packers     Vikings
# 118    2022     1  2022-09-11      Chiefs   Cardinals
# 119    2022     1  2022-09-11     Raiders    Chargers
# 121    2022     1  2022-09-11  Buccaneers     Cowboys
# 122    2022     1  2022-09-12     Broncos    Seahawks
#
#                      stadium             location  winner  proba_away  \
# 81              SoFi Stadium        Inglewood, CA       0      0.5555
# 82     Mercedes-Benz Stadium          Atlanta, GA       0      0.7982
# 108            Soldier Field          Chicago, IL       0      0.6197
# 109           Paycor Stadium       Cincinnati, OH       1      0.4791
# 110               Ford Field          Detroit, MI       0      0.6150
# 111        Hard Rock Stadium    Miami Gardens, FL       1      0.4633
# 112          MetLife Stadium  East Rutherford, NJ       0      0.6757
# 113               FedExField         Landover, MD       1      0.4462
# 114  Bank of America Stadium        Charlotte, NC       0      0.6045
# 115              NRG Stadium          Houston, TX       0      0.5243
# 116           Nissan Stadium        Nashville, TN       1      0.4674
# 117        U.S. Bank Stadium      Minneapolis, MN       0      0.6657
# 118       State Farm Stadium         Glendale, AZ       0      0.7457
# 119             SoFi Stadium        Inglewood, CA       0      0.5347
# 121             AT&T Stadium        Arlington, TX       0      0.5455
# 122              Lumen Field          Seattle, WA       1      0.3301
#
#      proba_home
# 81       0.4445
# 82       0.2018
# 108      0.3803
# 109      0.5209
# 110      0.3850
# 111      0.5367
# 112      0.3243
# 113      0.5538
# 114      0.3955
# 115      0.4757
# 116      0.5326
# 117      0.3343
# 118      0.2543
# 119      0.4653
# 121      0.4545
# 122      0.6699

# %%
res.to_csv("../05_results/results_games_2022_xgb.csv")

# %% [markdown]
# ## predicting the winner of the 2021 matches

# %%
df_2021 = dataset[dataset["season"]==2021]
df_other_year = dataset[dataset["season"]!=2021]

# %%
# Separate target variable Y from features X
print("Separating labels from features...")
target_variable = "winner_home"

X = df_other_year.drop(target_variable, axis = 1)
features_drop_list = {'idgame', 'location'}
X.drop(features_drop_list, axis=1, inplace=True)

Y = df_other_year.loc[:,target_variable]

# Automatically detect names of numeric/categorical columns
numeric_features = []
categorical_features = []
for i,t in X.dtypes.iteritems():
    if ('float' in str(t)) or ('int' in str(t)) :
        numeric_features.append(i)
    else :
        categorical_features.append(i)

# print('Found numeric features ', numeric_features)
# print('Found categorical features ', categorical_features)

# print("Dividing into train and test sets...")
# WARNING : don't forget stratify=Y for classification problems
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0, stratify = Y)


# Create pipeline for numeric features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')), # missing values will be replaced by columns' mean
    ('scaler', StandardScaler())
])

# Create pipeline for categorical features
#categorical_transformer = OneHotEncoder(drop='first') # no missing values in categorical data, so we only need the OHE

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')), # missing values will be replaced by most frequent value
    ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore')) # first column will be dropped to avoid creating correlations between features
    ])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Preprocessings on train set
# print("Performing preprocessings on train set...")
# print(X_train.head())
X_train = preprocessor.fit_transform(X_train)
# print('...Done preprocessing train set.')
# print(X_train)
# print('...Done.')
# print(X_train[0:5]) # MUST use this syntax because X_train is a numpy array and not a pandas DataFrame anymore
# print()
# Label encoding
# print("Encoding labels...")
# print(Y_train.head())
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
# print("...Done")
# print(Y_train[0:5])

# Preprocessings on test set
# print("Performing preprocessings on test set...")
# print(X_test.head()) 
X_test = preprocessor.transform(X_test) # Don't fit again !! The test set is used for validating decisions
# we made based on the training set, therefore we can only apply transformations that were parametered using the training set.
# Otherwise this creates what is called a leak from the test set which will introduce a bias in all your results.
# print('...Done.')
# print(X_test[0:5,:]) # MUST use this syntax because X_test is a numpy array and not a pandas DataFrame anymore
# print()
# Label encoding
# print("Encoding labels...")
# print(Y_test[0:5])
Y_test = encoder.transform(Y_test)
# print("...Done")
# print(Y_test[0:5])

model = XGBClassifier(
    objective= 'binary:logistic',
    nthread=-1,
    seed=42,
    learning_rate= 0.1, 
    max_depth= 2,
    min_child_weight= 3,
    n_estimators= 140
    )

model.fit(X_train, Y_train)

# %%
df_2021 = df_2021.reset_index()

# %%
X_2021 = df_2021.drop(target_variable, axis = 1)
features_drop_list = {'idgame', 'location'}
X_2021.drop(features_drop_list, axis=1, inplace=True)

Y_2021 = df_2021.loc[:,target_variable]

# %%
X_2021 = preprocessor.transform(X_2021)
Y_pred_2021 = pd.DataFrame(model.predict(X_2021), columns = ["pred_winner"])

# %%
res_2021 = pd.concat([df_2021,Y_pred_2021],axis=1)

# %%
accuracy_score(Y_2021, Y_pred_2021)
# Out:
# 0.7638376383763837

# %%
res_2021
# Out:
#      index  season  week  awayteam    hometeam     idgame  winner_home  \
# 0     1018    2021    15    Chiefs    Chargers  401326537            0
# 1     1019    2021     1     49ers       Lions  401326317            0
# 2     1020    2021    18   Bengals      Browns  401326588            1
# 3     1021    2021    18  Seahawks   Cardinals  401326597            0
# 4     1022    2021    18  Patriots    Dolphins  401326592            1
# ..     ...     ...   ...       ...         ...        ...          ...
# 266   1284    2021    12   Raiders     Cowboys  401326495            0
# 267   1285    2021    12     Bears       Lions  401326494            0
# 268   1286    2021    11    Giants  Buccaneers  401326493            1
# 269   1287    2021     2   Raiders    Steelers  401326356            0
# 270   1288    2021    18  Chargers     Raiders  401326600            1
#
#           home_coach      away_coach weather_type  ...  kicking_pts_MA_5_home  \
# 0     Brandon Staley       Andy Reid       cloudy  ...                    8.4
# 1       Dan Campbell   Kyle Shanahan       indoor  ...                    4.2
# 2    Kevin Stefanski      Zac Taylor         rain  ...                    3.6
# 3    Kliff Kingsbury    Pete Carroll        sunny  ...                    8.6
# 4       Brian Flores  Bill Belichick       cloudy  ...                    7.0
# ..               ...             ...          ...  ...                    ...
# 266    Mike McCarthy   Rich Bisaccia          NaN  ...                    6.6
# 267     Dan Campbell       Matt Nagy       indoor  ...                    5.8
# 268     Bruce Arians       Joe Judge       cloudy  ...                    6.2
# 269      Mike Tomlin      Jon Gruden        sunny  ...                    6.2
# 270    Rich Bisaccia  Brandon Staley          NaN  ...                    7.6
#
#      delta_day_away  delta_day_home                  stade           location  \
# 0               4.0             4.0           SoFi Stadium      Inglewood, CA
# 1             251.0           251.0             Ford Field        Detroit, MI
# 2               7.0             5.0    FirstEnergy Stadium      Cleveland, OH
# 3               7.0             7.0     State Farm Stadium       Glendale, AZ
# 4               7.0             7.0      Hard Rock Stadium  Miami Gardens, FL
# ..              ...             ...                    ...                ...
# 266             4.0             4.0           AT&T Stadium      Arlington, TX
# 267             3.0             3.0             Ford Field        Detroit, MI
# 268            15.0             8.0  Raymond James Stadium          Tampa, FL
# 269             5.0             7.0       Acrisure Stadium     Pittsburgh, PA
# 270             7.0             7.0      Allegiant Stadium      Las Vegas, NV
#
#      people  month  dayofmonth  dayofweek  pred_winner
# 0      98.0     12          17          4            0
# 1      92.0      9          12          6            0
# 2     100.0      1           9          6            1
# 3      98.0      1           9          6            0
# 4     100.0      1           9          6            1
# ..      ...    ...         ...        ...          ...
# 266    93.0     11          25          3            1
# 267    87.0     11          25          3            0
# 268   100.0     11          23          1            1
# 269    93.0      9          19          6            0
# 270    95.0      1          10          0            1
#
# [271 rows x 56 columns]

# %%
res_2021.to_csv("../05_results/prediction_xgb_games_2021.csv")

# %% [markdown]
# # ----------------- end of prediction 2021 -----------------
