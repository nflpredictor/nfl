# %%
import pandas as pd

# %%
df =pd.read_csv("../04_datasets/nfl_dataset_v1.csv")
df
# Out:
#       Unnamed: 0  season  week   awayteam    hometeam  awayscore  homescore  \
# 0              0    2017     9    Bengals     Jaguars          7         23
# 1              1    2017     9    Bengals     Jaguars          7         23
# 2              2    2017     4      Bills     Falcons         23         17
# 3              3    2017     4      Bills     Falcons         23         17
# 4              4    2017     4     Saints    Dolphins         20          0
# ...          ...     ...   ...        ...         ...        ...        ...
# 2537        2537    2021     5   Dolphins  Buccaneers         17         45
# 2538        2538    2021    15  Cardinals       Lions         12         30
# 2539        2539    2021    15  Cardinals       Lions         12         30
# 2540        2540    2021    18   Chargers     Raiders         32         35
# 2541        2541    2021    18   Chargers     Raiders         32         35
#
# ...

# %%
df.info(200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542 entries, 0 to 2541
# Data columns (total 139 columns):
#  #    Column                  Dtype
# ---   ------                  -----
#  0    Unnamed: 0              int64
#  1    season                  int64
#  2    week                    int64
#  3    awayteam                object
#  4    hometeam                object
#  5    awayscore               int64
#  6    homescore               int64
#  7    idgame                  int64
#  8    score_abs               int64
#  9    winner_home             int64
#  10   winner_away             int64
#  11   winner_team             object
#  12   concat                  object
#  13   home_coach              object
#  14   away_coach              object
#  15   location_x              object
#  16   weather_type            object
#  17   temperature             int64
#  18   humidity                int64
#  19   wind                    int64
#  20   game_date               object
# ...

# %%
df.loc[0:1,"delta_match"].apply(lambda x : x.split("days")[0])
# Out:
# 0     7
# 1    14
# Name: delta_match, dtype: object

# %%
df["delta_day"] = df["delta_match"].apply(lambda x : str(x).split("days")[0])

# %%
df["delta_day"].unique()
# Out:
# array(['7 ', '14 ', '6 ', '4 ', '8 ', '5 ', '9 ', '13 ', '10 ', '15 ',
#        '11 ', 'nan', '3 ', '12 ', '249 ', '258 ', '251 ', '253 ', '252 ',
#        '16 ', '260 ', '259 ', '256 ', '21 '], dtype=object)
